# %%
import os
import pandas as pd
import json
import codecs

# %%
# read the csv files into pandas as dataframes
filepath1 = os.path.join("belly_button_biodiversity_samples.csv")
samples_df = pd.read_csv(filepath1)

samples = list(samples_df.columns.values)
samples

# col = "BB_940"
# # samples_df.tail()
# # samples_df
# # samples_df.head()
# samples_df= samples_df[['otu_id',col]].sort_values(col, ascending=0)
# samples_df
# samples_df.columns = ['otu_id', "sample_values"]
# top_samples = samples_df.head(10)

# # samples_df = samples_df[samples_df['sample_values'] > 0]
# top_samples = top_samples.to_dict('list')
# top_samples

#new = samples_df.set_index('otu_id').stack().reset_index(name='value').rename(columns={'level_1':'sample_id'})
#new
#my_new = new.set_index('sample_id')
#my_new.groupby('sample_id').sum()



# def make_dictionary(sample_id, df):
#     sample = {"sampleid": sample_id}
#     for otu_id, value in df[['otu_id', sample_id]].iterrows():
#         otu_id = {}
#         otu_id[otu_id] = value
#         sample["otu_ids"] = otu_id
#     return sample

# samples_df[['otu_id','BB_940']].query('BB_940 > 1').head()

# samples_df.apply(func=make_dictionary, axis=1)

# # make_dictionary('BB_940', samples_df)
# samples_df.set_index('otu_id')
# t_df = samples_df.T
# t_df
# t_df.columns = t_df.iloc[0]
# t_df
# t_df = t_df.drop('otu_id')
# t_df

# # t_df = t_df.to_dict(orient="index")
# # t_df
# # with open('data.txt', 'w') as f:
# #     j_str = json.dump(t_df,f,ensure_ascii=False,indent=4)

# # with open('data.txt', 'w') as f:
# #      json.dump(df_json, f, ensure_ascii=False)


    
# # t_df
# t_df
# samples_df.head()
# Out:
# ['otu_id',
#  'BB_940',
#  'BB_941',
#  'BB_943',
#  'BB_944',
#  'BB_945',
#  'BB_946',
#  'BB_947',
#  'BB_948',
#  'BB_949',
#  'BB_950',
#  'BB_952',
#  'BB_953',
#  'BB_954',
#  'BB_955',
#  'BB_956',
#  'BB_958',
#  'BB_959',
#  'BB_960',
#  'BB_961',
#  'BB_962',
#  'BB_963',
#  'BB_964',
#  'BB_966',
#  'BB_967',
#  'BB_968',
#  'BB_969',
#  'BB_970',
#  'BB_971',
#  'BB_972',
#  'BB_973',
#  'BB_974',
#  'BB_975',
#  'BB_978',
#  'BB_1233',
#  'BB_1234',
#  'BB_1235',
#  'BB_1236',
#  'BB_1237',
#  'BB_1238',
#  'BB_1242',
#  'BB_1243',
#  'BB_1246',
#  'BB_1253',
#  'BB_1254',
#  'BB_1258',
#  'BB_1259',
#  'BB_1260',
#  'BB_1264',
#  'BB_1265',
#  'BB_1273',
#  'BB_1275',
#  'BB_1276',
#  'BB_1277',
#  'BB_1278',
#  'BB_1279',
#  'BB_1280',
#  'BB_1281',
#  'BB_1282',
#  'BB_1283',
#  'BB_1284',
#  'BB_1285',
#  'BB_1286',
#  'BB_1287',
#  'BB_1288',
#  'BB_1289',
#  'BB_1290',
#  'BB_1291',
#  'BB_1292',
#  'BB_1293',
#  'BB_1294',
#  'BB_1295',
#  'BB_1296',
#  'BB_1297',
#  'BB_1298',
#  'BB_1308',
#  'BB_1309',
#  'BB_1310',
#  'BB_1374',
#  'BB_1415',
#  'BB_1439',
#  'BB_1441',
#  'BB_1443',
#  'BB_1486',
#  'BB_1487',
#  'BB_1489',
#  'BB_1490',
#  'BB_1491',
#  'BB_1494',
#  'BB_1495',
#  'BB_1497',
#  'BB_1499',
#  'BB_1500',
#  'BB_1501',
#  'BB_1502',
#  'BB_1503',
#  'BB_1504',
#  'BB_1505',
#  'BB_1506',
#  'BB_1507',
#  'BB_1508',
#  'BB_1510',
#  'BB_1511',
#  'BB_1512',
#  'BB_1513',
#  'BB_1514',
#  'BB_1515',
#  'BB_1516',
#  'BB_1517',
#  'BB_1518',
#  'BB_1519',
#  'BB_1521',
#  'BB_1524',
#  'BB_1526',
#  'BB_1527',
#  'BB_1530',
#  'BB_1531',
#  'BB_1532',
#  'BB_1533',
#  'BB_1534',
#  'BB_1535',
#  'BB_1536',
#  'BB_1537',
#  'BB_1539',
#  'BB_1540',
#  'BB_1541',
#  'BB_1542',
#  'BB_1543',
#  'BB_1544',
#  'BB_1545',
#  'BB_1546',
#  'BB_1547',
#  'BB_1548',
#  'BB_1549',
#  'BB_1550',
#  'BB_1551',
#  'BB_1552',
#  'BB_1553',
#  'BB_1554',
#  'BB_1555',
#  'BB_1556',
#  'BB_1557',
#  'BB_1558',
#  'BB_1561',
#  'BB_1562',
#  'BB_1563',
#  'BB_1564',
#  'BB_1572',
#  'BB_1573',
#  'BB_1574',
#  'BB_1576',
#  'BB_1577',
#  'BB_1581',
#  'BB_1601']

# %%
# read the csv files into pandas as dataframes
filepath2 = os.path.join("belly_button_biodiversity_otu_id.csv")
otu_df = pd.read_csv(filepath2)
otu_df.head(),mn
otu_description = list(otu_df.lowest_taxonomic_unit_found)
otu_description
otu_df.tail()
# Out:
#       otu_id lowest_taxonomic_unit_found
# 3669    3670                Unclassified
# 3670    3671                Unclassified
# 3671    3672                Unclassified
# 3672    3673                Unclassified
# 3673    3674                Unclassified

# %%
# read the csv files into pandas as dataframes
filepath3 = os.path.join("belly_button_biodiversity_MetaData.csv")
metaData_df = pd.read_csv(filepath3)
metaData_df = metaData_df[['AGE','BBTYPE','ETHNICITY','GENDER','LOCATION','WFREQ','SAMPLEID']]

sample_metaData = metaData_df.to_dict('records')
sample_metaData
# Out:
# [{'AGE': 24.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Beaufort/NC',
#   'SAMPLEID': 940,
#   'WFREQ': 2.0},
#  {'AGE': 34.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian/Midleastern',
#   'GENDER': 'F',
#   'LOCATION': 'Chicago/IL',
#   'SAMPLEID': 941,
#   'WFREQ': 1.0},
#  {'AGE': 49.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Omaha/NE',
#   'SAMPLEID': 943,
#   'WFREQ': 1.0},
#  {'AGE': 44.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'European',
#   'GENDER': 'M',
#   'LOCATION': 'NewHaven/CT',
#   'SAMPLEID': 944,
#   'WFREQ': 1.0},
#  {'AGE': 48.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Philidelphia/PA',
#   'SAMPLEID': 945,
#   'WFREQ': 1.0},
#  {'AGE': 42.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Deerfield/MA',
#   'SAMPLEID': 946,
#   'WFREQ': 3.0},
#  {'AGE': 49.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'ChapelHill/NC',
#   'SAMPLEID': 947,
#   'WFREQ': 6.0},
#  {'AGE': 20.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'ChapelHill/NC',
#   'SAMPLEID': 948,
#   'WFREQ': nan},
#  {'AGE': 51.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Durham/NC',
#   'SAMPLEID': 949,
#   'WFREQ': 3.0},
#  {'AGE': 51.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NewYork/NY',
#   'SAMPLEID': 950,
#   'WFREQ': 5.0},
#  {'AGE': 51.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Seattle/WA',
#   'SAMPLEID': 952,
#   'WFREQ': 7.0},
#  {'AGE': 38.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Chicago/IL',
#   'SAMPLEID': 953,
#   'WFREQ': 2.0},
#  {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NewYork/NY',
#   'SAMPLEID': 954,
#   'WFREQ': 7.0},
#  {'AGE': 27.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NewYork/NY',
#   'SAMPLEID': 955,
#   'WFREQ': 7.0},
#  {'AGE': 16.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Jacksonville/NC',
#   'SAMPLEID': 956,
#   'WFREQ': 7.0},
#  {'AGE': 43.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Wilmington/NC',
#   'SAMPLEID': 958,
#   'WFREQ': 5.0},
#  {'AGE': 40.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Carrboro/NC',
#   'SAMPLEID': 959,
#   'WFREQ': 5.0},
#  {'AGE': 48.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Lexington/NC',
#   'SAMPLEID': 960,
#   'WFREQ': 7.0},
#  {'AGE': 35.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Edmonton,AB',
#   'SAMPLEID': 961,
#   'WFREQ': 4.0},
#  {'AGE': 56.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Washington,DC',
#   'SAMPLEID': 962,
#   'WFREQ': 1.0},
#  {'AGE': 33.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Ithaca/NY',
#   'SAMPLEID': 963,
#   'WFREQ': 3.5},
#  {'AGE': 43.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'UK/London',
#   'SAMPLEID': 964,
#   'WFREQ': 7.0},
#  {'AGE': 56.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Needham/MA',
#   'SAMPLEID': 966,
#   'WFREQ': 0.0},
#  {'AGE': 43.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian/Jewish',
#   'GENDER': 'F',
#   'LOCATION': 'ChapelHill/NC',
#   'SAMPLEID': 967,
#   'WFREQ': 1.0},
#  {'AGE': 38.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'St.Louis/MI',
#   'SAMPLEID': 968,
#   'WFREQ': 6.0},
#  {'AGE': 31.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian/Asian',
#   'GENDER': 'F',
#   'LOCATION': 'ChevyChase/MD',
#   'SAMPLEID': 969,
#   'WFREQ': 7.0},
#  {'AGE': 42.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'SanDiego/CA',
#   'SAMPLEID': 970,
#   'WFREQ': 0.0},
#  {'AGE': 36.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Asian(South)',
#   'GENDER': 'M',
#   'LOCATION': 'SantaBarbara/CA',
#   'SAMPLEID': 971,
#   'WFREQ': 1.0},
#  {'AGE': 31.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Charlotte/NC',
#   'SAMPLEID': 972,
#   'WFREQ': 7.0},
#  {'AGE': 4.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Charlotte/NC',
#   'SAMPLEID': 973,
#   'WFREQ': 1.0},
#  {'AGE': 57.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh/NC',
#   'SAMPLEID': 974,
#   'WFREQ': nan},
#  {'AGE': 60.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NewCanaan/CT',
#   'SAMPLEID': 975,
#   'WFREQ': 3.0},
#  {'AGE': 21.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Hispanic',
#   'GENDER': 'F',
#   'LOCATION': 'Durham/NC',
#   'SAMPLEID': 978,
#   'WFREQ': nan},
#  {'AGE': 34.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1233,
#   'WFREQ': 0.0},
#  {'AGE': nan,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1234,
#   'WFREQ': nan},
#  {'AGE': 43.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1235,
#   'WFREQ': 0.0},
#  {'AGE': 54.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1236,
#   'WFREQ': 6.0},
#  {'AGE': 9.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'ChapelHill,NC',
#   'SAMPLEID': 1237,
#   'WFREQ': 2.0},
#  {'AGE': 41.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1238,
#   'WFREQ': 0.0},
#  {'AGE': 44.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1242,
#   'WFREQ': 1.0},
#  {'AGE': 49.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1243,
#   'WFREQ': nan},
#  {'AGE': 2.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Atlanta,GA',
#   'SAMPLEID': 1246,
#   'WFREQ': 7.0},
#  {'AGE': 24.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Voss,NC',
#   'SAMPLEID': 1253,
#   'WFREQ': 5.0},
#  {'AGE': 1.0,
#   'BBTYPE': 'o',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Voss,NC',
#   'SAMPLEID': 1254,
#   'WFREQ': 5.0},
#  {'AGE': 31.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'f',
#   'LOCATION': 'Smithfield,NC',
#   'SAMPLEID': 1258,
#   'WFREQ': 7.0},
#  {'AGE': 33.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'm',
#   'LOCATION': 'Smithfield,NC',
#   'SAMPLEID': 1259,
#   'WFREQ': 7.0},
#  {'AGE': 10.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'm',
#   'LOCATION': 'Smithfield,NC',
#   'SAMPLEID': 1260,
#   'WFREQ': 7.0},
#  {'AGE': 46.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'm',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1264,
#   'WFREQ': 0.0},
#  {'AGE': 10.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'f',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1265,
#   'WFREQ': 0.0},
#  {'AGE': 60.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1273,
#   'WFREQ': 3.0},
#  {'AGE': 18.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1275,
#   'WFREQ': 0.0},
#  {'AGE': 34.0,
#   'BBTYPE': 'O',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1276,
#   'WFREQ': 0.0},
#  {'AGE': 67.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1277,
#   'WFREQ': 7.0},
#  {'AGE': 44.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': nan,
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1278,
#   'WFREQ': 7.0},
#  {'AGE': 60.0,
#   'BBTYPE': 'O',
#   'ETHNICITY': 'Black',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1279,
#   'WFREQ': 9.0},
#  {'AGE': 30.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'PacificIslander',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1280,
#   'WFREQ': nan},
#  {'AGE': 55.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1281,
#   'WFREQ': 3.0},
#  {'AGE': 53.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1282,
#   'WFREQ': nan},
#  {'AGE': 48.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1283,
#   'WFREQ': 7.0},
#  {'AGE': 30.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1284,
#   'WFREQ': 7.0},
#  {'AGE': 42.0,
#   'BBTYPE': 'Both',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1285,
#   'WFREQ': nan},
#  {'AGE': 38.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1286,
#   'WFREQ': 7.0},
#  {'AGE': 46.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1287,
#   'WFREQ': nan},
#  {'AGE': 52.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1288,
#   'WFREQ': 7.0},
#  {'AGE': 38.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Black',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1289,
#   'WFREQ': nan},
#  {'AGE': 53.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1290,
#   'WFREQ': 5.0},
#  {'AGE': 49.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1291,
#   'WFREQ': 0.0},
#  {'AGE': 46.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': nan,
#   'SAMPLEID': 1292,
#   'WFREQ': nan},
#  {'AGE': 68.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1293,
#   'WFREQ': 1.0},
#  {'AGE': 46.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1294,
#   'WFREQ': nan},
#  {'AGE': 48.0,
#   'BBTYPE': 'Both',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': nan,
#   'SAMPLEID': 1295,
#   'WFREQ': 7.0},
#  {'AGE': 10.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'Black',
#   'GENDER': 'f',
#   'LOCATION': 'Pinehurst,NC',
#   'SAMPLEID': 1296,
#   'WFREQ': 4.0},
#  {'AGE': 10.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Caucasion',
#   'GENDER': 'f',
#   'LOCATION': 'Pinehurst,NC',
#   'SAMPLEID': 1297,
#   'WFREQ': 5.0},
#  {'AGE': 12.0,
#   'BBTYPE': 'i',
#   'ETHNICITY': 'White',
#   'GENDER': 'm',
#   'LOCATION': 'Pinehurst,NC',
#   'SAMPLEID': 1298,
#   'WFREQ': 3.0},
#  {'AGE': 40.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Black',
#   'GENDER': 'f',
#   'LOCATION': 'Durham,NC',
#   'SAMPLEID': 1308,
#   'WFREQ': 7.0},
#  {'AGE': 6.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Black',
#   'GENDER': 'f',
#   'LOCATION': 'Durham,NC',
#   'SAMPLEID': 1309,
#   'WFREQ': 5.0},
#  {'AGE': 3.0,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Black',
#   'GENDER': 'm',
#   'LOCATION': 'Durham,NC',
#   'SAMPLEID': 1310,
#   'WFREQ': 5.0},
#  {'AGE': 55.0,
#   'BBTYPE': 'o',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Cary,NC',
#   'SAMPLEID': 1374,
#   'WFREQ': 7.0},
#  {'AGE': nan,
#   'BBTYPE': 'Unknown',
#   'ETHNICITY': nan,
#   'GENDER': nan,
#   'LOCATION': nan,
#   'SAMPLEID': 1415,
#   'WFREQ': nan},
#  {'AGE': nan,
#   'BBTYPE': nan,
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Sarasota,FL',
#   'SAMPLEID': 1439,
#   'WFREQ': nan},
#  {'AGE': 36.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1441,
#   'WFREQ': 4.0},
#  {'AGE': 57.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1443,
#   'WFREQ': 3.0},
#  {'AGE': 33.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Shrewsbury,UK',
#   'SAMPLEID': 1486,
#   'WFREQ': 0.0},
#  {'AGE': 30.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Shrewsbury,UK',
#   'SAMPLEID': 1487,
#   'WFREQ': 0.0},
#  {'AGE': 28.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'WashingtonDC',
#   'SAMPLEID': 1489,
#   'WFREQ': 0.0},
#  {'AGE': 27.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'DurhamNC',
#   'SAMPLEID': 1490,
#   'WFREQ': 0.0},
#  {'AGE': 24.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'WashingtonDC',
#   'SAMPLEID': 1491,
#   'WFREQ': 3.0},
#  {'AGE': 35.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Boone,NC',
#   'SAMPLEID': 1494,
#   'WFREQ': 0.0},
#  {'AGE': 57.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1495,
#   'WFREQ': 3.0},
#  {'AGE': 35.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1497,
#   'WFREQ': 0.0},
#  {'AGE': 33.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Waynesville,NC',
#   'SAMPLEID': 1499,
#   'WFREQ': 0.0},
#  {'AGE': 32.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1500,
#   'WFREQ': 0.0},
#  {'AGE': 38.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': nan,
#   'GENDER': 'M',
#   'LOCATION': 'FallsChurch,VA',
#   'SAMPLEID': 1501,
#   'WFREQ': 0.0},
#  {'AGE': 27.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Boone,NC',
#   'SAMPLEID': 1502,
#   'WFREQ': 0.0},
#  {'AGE': 32.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1503,
#   'WFREQ': 7.0},
#  {'AGE': 27.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1504,
#   'WFREQ': 0.0},
#  {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Durham,NC',
#   'SAMPLEID': 1505,
#   'WFREQ': 0.0},
#  {'AGE': 21.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'Raleigh,NC',
#   'SAMPLEID': 1506,
#   'WFREQ': 0.0},
#  {'AGE': 46.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1507,
#   'WFREQ': 0.0},
#  {'AGE': 60.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1508,
#   'WFREQ': 0.0},
#  {'AGE': 21.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Black',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1510,
#   'WFREQ': 1.0},
#  {'AGE': 46.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1511,
#   'WFREQ': 0.0},
#  {'AGE': 55.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1512,
#   'WFREQ': 7.0},
#  {'AGE': 15.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1513,
#   'WFREQ': 0.0},
#  {'AGE': 3.0,
#   'BBTYPE': 'o',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1514,
#   'WFREQ': 7.0},
#  {'AGE': 51.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1515,
#   'WFREQ': 1.0},
#  {'AGE': 57.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1516,
#   'WFREQ': 0.0},
#  {'AGE': 27.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1517,
#   'WFREQ': 0.0},
#  {'AGE': 25.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'GA',
#   'SAMPLEID': 1518,
#   'WFREQ': 0.0},
#  {'AGE': 25.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1519,
#   'WFREQ': 0.0},
#  {'AGE': 10.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1521,
#   'WFREQ': 0.0},
#  {'AGE': 14.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1524,
#   'WFREQ': 4.0},
#  {'AGE': 6.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1526,
#   'WFREQ': 7.0},
#  {'AGE': 34.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1527,
#   'WFREQ': 7.0},
#  {'AGE': 54.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1530,
#   'WFREQ': 1.0},
#  {'AGE': 39.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1531,
#   'WFREQ': 2.0},
#  {'AGE': 38.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1532,
#   'WFREQ': 0.0},
#  {'AGE': 37.0,
#   'BBTYPE': 'o',
#   'ETHNICITY': 'Black',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1533,
#   'WFREQ': 0.0},
#  {'AGE': 42.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1534,
#   'WFREQ': 0.0},
#  {'AGE': 35.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1535,
#   'WFREQ': 7.0},
#  {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1536,
#   'WFREQ': 7.0},
#  {'AGE': 28.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1537,
#   'WFREQ': 0.0},
#  {'AGE': 39.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1539,
#   'WFREQ': 7.0},
#  {'AGE': 30.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1540,
#   'WFREQ': 0.0},
#  {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1541,
#   'WFREQ': 0.0},
#  {'AGE': 36.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1542,
#   'WFREQ': nan},
#  {'AGE': 34.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1543,
#   'WFREQ': 3.0},
#  {'AGE': 33.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1544,
#   'WFREQ': 1.0},
#  {'AGE': 39.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1545,
#   'WFREQ': 7.0},
#  {'AGE': 34.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1546,
#   'WFREQ': 3.0},
#  {'AGE': 38.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': nan,
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1547,
#   'WFREQ': 0.0},
#  {'AGE': 6.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1548,
#   'WFREQ': 0.0},
#  {'AGE': 37.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1549,
#   'WFREQ': 3.0},
#  {'AGE': 29.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1550,
#   'WFREQ': 7.0},
#  {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1551,
#   'WFREQ': 0.0},
#  {'AGE': 25.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1552,
#   'WFREQ': 3.0},
#  {'AGE': 50.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1553,
#   'WFREQ': 0.0},
#  {'AGE': 18.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1554,
#   'WFREQ': 0.0},
#  {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1555,
#   'WFREQ': 0.0},
#  {'AGE': 34.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Hispanic',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1556,
#   'WFREQ': 0.0},
#  {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1557,
#   'WFREQ': 2.0},
#  {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1558,
#   'WFREQ': 1.0},
#  {'AGE': 31.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1561,
#   'WFREQ': 2.0},
#  {'AGE': 39.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'MT',
#   'SAMPLEID': 1562,
#   'WFREQ': 0.0},
#  {'AGE': 31.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'MT',
#   'SAMPLEID': 1563,
#   'WFREQ': 0.0},
#  {'AGE': 36.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1564,
#   'WFREQ': 5.0},
#  {'AGE': 33.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1572,
#   'WFREQ': 0.0},
#  {'AGE': 53.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1573,
#   'WFREQ': 0.0},
#  {'AGE': 30.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'OK',
#   'SAMPLEID': 1574,
#   'WFREQ': 7.0},
#  {'AGE': 33.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1576,
#   'WFREQ': 0.0},
#  {'AGE': 26.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'M',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1577,
#   'WFREQ': 0.0},
#  {'AGE': 22.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Asian(American)',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1581,
#   'WFREQ': 2.0},
#  {'AGE': 22.0,
#   'BBTYPE': 'I',
#   'ETHNICITY': 'Caucasian',
#   'GENDER': 'F',
#   'LOCATION': 'NC',
#   'SAMPLEID': 1601,
#   'WFREQ': 2.0}]

# %%
# read the csv files into pandas as dataframes
filepath4 = os.path.join("metadata_columns.csv")
metaDataColumns_df = pd.read_csv(filepath4)
metaDataColumns_df.head()
# Out:
#       COLUMN     TYPE           DESCRIPTION
# 0   SAMPLEID  INTEGER             sample_id
# 1      EVENT     TEXT     Collection event
# 2  ETHNICITY     TEXT             Ethnicity
# 3     GENDER     TEXT  Gender (male/female)
# 4        AGE  INTEGER        Age (in years)
